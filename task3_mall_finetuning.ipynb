# %% [markdown]
# # Task 3 — Fine-Tuning CSRNet on Mall CCTV Frames
#
# In this task, the pre-trained CSRNet model is adapted to a new indoor CCTV
# environment (shopping mall scenes). Since the dataset contains only images
# without ground-truth annotations, a weakly supervised fine-tuning strategy
# is adopted.
#
# YOLO is used to generate pseudo head-point annotations, which are converted
# into density maps. CSRNet is then fine-tuned on these pseudo-labels to improve
# performance in real-world indoor surveillance scenarios.

# %%
# ======================================================
# Imports & Global Setup
# ======================================================

import os
import glob
import cv2
import numpy as np
from scipy.ndimage import gaussian_filter

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

print("PyTorch version:", torch.__version__)
# Out:
# PyTorch version: 2.9.0+cpu

# %%
# ======================================================
# Device Configuration
# ======================================================

DEVICE = torch.device("cpu")
print("Using device:", DEVICE)
# Out:
# Using device: cpu

# %%
# ====================
# CSRNet Architecture 
# ====================

from torchvision import models

class CSRNet(nn.Module):
    def __init__(self, load_pretrained_vgg=False):
        super().__init__()

        if load_pretrained_vgg:
            from torchvision.models import VGG16_Weights
            vgg = models.vgg16(weights=VGG16_Weights.IMAGENET1K_V1)
        else:
            vgg = models.vgg16(weights=None)

        # Frontend: VGG16 conv layers up to conv4_3
        self.frontend = nn.Sequential(*list(vgg.features.children())[:23])

        # Backend: dilated convolutions (ENDS AT 64 CHANNELS)
        self.backend = nn.Sequential(
            nn.Conv2d(512, 512, 3, padding=2, dilation=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=2, dilation=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=2, dilation=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 256, 3, padding=2, dilation=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 128, 3, padding=2, dilation=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, 3, padding=2, dilation=2),
            nn.ReLU(inplace=True),
        )

        self.output_layer = nn.Conv2d(64, 1, 1)

    def forward(self, x):
        x = self.frontend(x)
        x = self.backend(x)
        x = self.output_layer(x)
        return x

# %%
# ======================================================
# Load Pre-Trained CSRNet Weights
# ======================================================

PRETRAINED_PATH = "csrnet_weights.pth"   # from Task 1

assert os.path.exists(PRETRAINED_PATH), "Pre-trained CSRNet weights not found"

model = CSRNet().to(DEVICE)
state = torch.load(PRETRAINED_PATH, map_location=DEVICE)
model.load_state_dict(state)

print("Loaded pre-trained CSRNet weights.")
# Out:
# Loaded pre-trained CSRNet weights.

# %%
# ======================================================
# Freeze Frontend Layers
# ======================================================

for name, param in model.named_parameters():
    if "frontend" in name:
        param.requires_grad = False

print("Frozen CSRNet frontend layers.")
# Out:
# Frozen CSRNet frontend layers.

# %%
# ======================================================
# Inspect Mall Dataset
# ======================================================

MALL_DATA_ROOT = "C:\\Users\\ARTI\\OneDrive\\Desktop\\projects\\cd\\archive (1)" 

image_paths = []
for ext in ("*.jpg", "*.png", "*.jpeg"):
    image_paths.extend(
        glob.glob(os.path.join(MALL_DATA_ROOT, "**", ext), recursive=True)
    )

assert len(image_paths) > 0, "No images found in Mall dataset"

print(f"Total Mall frames found: {len(image_paths)}")
print("Sample image:", image_paths[0])
# Out:
# Total Mall frames found: 2000
# Sample image: C:\Users\ARTI\OneDrive\Desktop\projects\cd\archive (1)\frames\frames\seq_000001.jpg

# %%
# ======================================================
# Generate Density Map from YOLO Detections
# ======================================================

def generate_density_from_boxes(boxes, shape, sigma=6):
    density = np.zeros(shape, dtype=np.float32)

    for box in boxes:
        x1, y1, x2, y2 = map(int, box)
        cx = int((x1 + x2) / 2)
        cy = int((y1 + y2) / 2)

        if 0 <= cy < shape[0] and 0 <= cx < shape[1]:
            density[cy, cx] += 1

    density = gaussian_filter(density, sigma=sigma)
    return density

# %%
# ======================================================
# YOLO Initialization (for pseudo-label generation)
# ======================================================

try:
    from ultralytics import YOLO
except ImportError as e:
    raise ImportError(
        "Ultralytics YOLO not installed.\n"
        "Install with: pip install ultralytics"
    )

# Load lightweight YOLOv8 model (CPU-safe)
yolo = YOLO("yolov8n.pt")
yolo.fuse()

print("YOLO loaded successfully for pseudo-labeling.")
# Out:
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
# YOLO loaded successfully for pseudo-labeling.

# %%
# ======================================================
# Mall CCTV Dataset (Pseudo-Labeled)
# ======================================================

class MallPseudoDataset(Dataset):
    def __init__(self, image_paths):
        self.image_paths = image_paths

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]

        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # YOLO pseudo-labels
        results = yolo(image, conf=0.4, classes=[0])[0]
        boxes = results.boxes.xyxy.cpu().numpy() if results.boxes is not None else []

        density = generate_density_from_boxes(
            boxes,
            shape=image.shape[:2]
        )

        image = image.astype(np.float32) / 255.0
        image = torch.from_numpy(image).permute(2, 0, 1)
        density = torch.from_numpy(density).unsqueeze(0)

        return image, density

# %%
# ======================================================
# Fine-Tuning Configuration
# ======================================================

FT_EPOCHS = 3
FT_LR = 1e-6
BATCH_SIZE = 1

# %%
# ======================================================
# DataLoader & Optimizer
# ======================================================

dataset = MallPseudoDataset(image_paths)
loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=FT_LR
)

# %%
# ======================================================
# Fine-Tuning Loop
# ======================================================

model.train()

for epoch in range(1, FT_EPOCHS + 1):
    running_loss = 0.0

    for img, gt in loader:
        img = img.to(DEVICE)
        gt = gt.to(DEVICE)

        pred = model(img)

        if pred.shape != gt.shape:
            gt = nn.functional.interpolate(gt, size=pred.shape[2:])

        loss = criterion(pred, gt)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(loader)
    print(f"[Task 3] Epoch {epoch}/{FT_EPOCHS} - Loss: {avg_loss:.6f}")
# Out:
# 0: 480x640 10 persons, 372.5ms
# Speed: 19.7ms preprocess, 372.5ms inference, 42.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 persons, 180.5ms
# Speed: 4.1ms preprocess, 180.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 224.8ms
# Speed: 9.0ms preprocess, 224.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 181.8ms
# Speed: 2.9ms preprocess, 181.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 236.3ms
# Speed: 6.2ms preprocess, 236.3ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 447.1ms
# Speed: 12.5ms preprocess, 447.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 495.3ms
# Speed: 25.1ms preprocess, 495.3ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 517.7ms
# Speed: 12.6ms preprocess, 517.7ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 383.2ms
# Speed: 7.6ms preprocess, 383.2ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 418.4ms
# Speed: 8.6ms preprocess, 418.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 245.3ms
# Speed: 3.4ms preprocess, 245.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 398.3ms
# Speed: 12.3ms preprocess, 398.3ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 200.9ms
# Speed: 5.2ms preprocess, 200.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 204.1ms
# Speed: 6.3ms preprocess, 204.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 583.2ms
# Speed: 24.7ms preprocess, 583.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 191.0ms
# Speed: 12.3ms preprocess, 191.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 179.8ms
# Speed: 2.7ms preprocess, 179.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 173.5ms
# Speed: 5.5ms preprocess, 173.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 168.5ms
# Speed: 5.5ms preprocess, 168.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 195.0ms
# Speed: 5.9ms preprocess, 195.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 319.5ms
# Speed: 3.7ms preprocess, 319.5ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 283.5ms
# Speed: 8.5ms preprocess, 283.5ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 342.4ms
# Speed: 4.6ms preprocess, 342.4ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 434.8ms
# Speed: 8.6ms preprocess, 434.8ms inference, 11.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 185.7ms
# Speed: 2.8ms preprocess, 185.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 179.0ms
# Speed: 6.4ms preprocess, 179.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 172.0ms
# Speed: 2.7ms preprocess, 172.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 177.8ms
# Speed: 5.9ms preprocess, 177.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 persons, 244.3ms
# Speed: 4.8ms preprocess, 244.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 180.9ms
# Speed: 6.1ms preprocess, 180.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 190.9ms
# Speed: 3.4ms preprocess, 190.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 171.5ms
# Speed: 5.4ms preprocess, 171.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 persons, 176.1ms
# Speed: 2.7ms preprocess, 176.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 persons, 225.5ms
# Speed: 7.4ms preprocess, 225.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 219.0ms
# Speed: 6.2ms preprocess, 219.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 211.3ms
# Speed: 2.6ms preprocess, 211.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 347.8ms
# Speed: 11.2ms preprocess, 347.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 440.1ms
# Speed: 14.0ms preprocess, 440.1ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 232.6ms
# Speed: 2.7ms preprocess, 232.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 180.8ms
# Speed: 5.3ms preprocess, 180.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 168.4ms
# Speed: 2.6ms preprocess, 168.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 235.5ms
# Speed: 5.3ms preprocess, 235.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 322.6ms
# Speed: 4.1ms preprocess, 322.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 304.7ms
# Speed: 10.8ms preprocess, 304.7ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 276.8ms
# Speed: 11.1ms preprocess, 276.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 314.2ms
# Speed: 10.5ms preprocess, 314.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 1017.4ms
# Speed: 56.2ms preprocess, 1017.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 458.0ms
# Speed: 9.3ms preprocess, 458.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 184.6ms
# Speed: 2.9ms preprocess, 184.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 persons, 184.4ms
# Speed: 2.6ms preprocess, 184.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 228.2ms
# Speed: 6.3ms preprocess, 228.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 321.4ms
# Speed: 4.6ms preprocess, 321.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 538.0ms
# Speed: 6.4ms preprocess, 538.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 314.6ms
# Speed: 3.3ms preprocess, 314.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 328.5ms
# Speed: 4.4ms preprocess, 328.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 309.2ms
# Speed: 3.9ms preprocess, 309.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 330.2ms
# Speed: 6.6ms preprocess, 330.2ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 391.9ms
# Speed: 10.6ms preprocess, 391.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 298.0ms
# Speed: 4.8ms preprocess, 298.0ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 243.0ms
# Speed: 6.0ms preprocess, 243.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 191.2ms
# Speed: 3.2ms preprocess, 191.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 211.2ms
# Speed: 8.8ms preprocess, 211.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 248.3ms
# Speed: 3.5ms preprocess, 248.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 232.1ms
# Speed: 8.0ms preprocess, 232.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 234.6ms
# Speed: 3.3ms preprocess, 234.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 241.5ms
# Speed: 5.1ms preprocess, 241.5ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 222.0ms
# Speed: 3.2ms preprocess, 222.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 241.6ms
# Speed: 2.9ms preprocess, 241.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 241.3ms
# Speed: 4.5ms preprocess, 241.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 239.2ms
# Speed: 7.0ms preprocess, 239.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 266.4ms
# Speed: 3.0ms preprocess, 266.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 305.6ms
# Speed: 11.6ms preprocess, 305.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 748.7ms
# Speed: 5.9ms preprocess, 748.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 353.6ms
# Speed: 5.7ms preprocess, 353.6ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 238.9ms
# Speed: 5.9ms preprocess, 238.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 persons, 509.0ms
# Speed: 4.7ms preprocess, 509.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 346.9ms
# Speed: 7.2ms preprocess, 346.9ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 228.9ms
# Speed: 5.4ms preprocess, 228.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 199.0ms
# Speed: 8.4ms preprocess, 199.0ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 208.3ms
# Speed: 5.1ms preprocess, 208.3ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 223.4ms
# Speed: 5.1ms preprocess, 223.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 228.7ms
# Speed: 6.4ms preprocess, 228.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 298.5ms
# Speed: 5.5ms preprocess, 298.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 294.9ms
# Speed: 3.9ms preprocess, 294.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 311.8ms
# Speed: 10.5ms preprocess, 311.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 353.6ms
# Speed: 4.6ms preprocess, 353.6ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 415.4ms
# Speed: 30.8ms preprocess, 415.4ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 persons, 300.4ms
# Speed: 8.2ms preprocess, 300.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 338.9ms
# Speed: 10.1ms preprocess, 338.9ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 414.9ms
# Speed: 10.8ms preprocess, 414.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 259.5ms
# Speed: 8.8ms preprocess, 259.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 26 persons, 469.5ms
# Speed: 13.4ms preprocess, 469.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 353.1ms
# Speed: 7.9ms preprocess, 353.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 293.4ms
# Speed: 3.8ms preprocess, 293.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 336.3ms
# Speed: 5.0ms preprocess, 336.3ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 385.0ms
# Speed: 8.4ms preprocess, 385.0ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 328.1ms
# Speed: 18.3ms preprocess, 328.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 290.0ms
# Speed: 7.8ms preprocess, 290.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 286.3ms
# Speed: 4.7ms preprocess, 286.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 persons, 330.6ms
# Speed: 9.9ms preprocess, 330.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 310.7ms
# Speed: 5.8ms preprocess, 310.7ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 331.9ms
# Speed: 10.5ms preprocess, 331.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 283.8ms
# Speed: 5.0ms preprocess, 283.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 338.0ms
# Speed: 7.4ms preprocess, 338.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 327.4ms
# Speed: 6.1ms preprocess, 327.4ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 266.4ms
# Speed: 5.0ms preprocess, 266.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 369.7ms
# Speed: 9.2ms preprocess, 369.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 260.8ms
# Speed: 5.4ms preprocess, 260.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 626.0ms
# Speed: 8.2ms preprocess, 626.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 219.9ms
# Speed: 6.0ms preprocess, 219.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 212.7ms
# Speed: 3.7ms preprocess, 212.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 272.4ms
# Speed: 10.8ms preprocess, 272.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 230.4ms
# Speed: 3.4ms preprocess, 230.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 389.9ms
# Speed: 4.5ms preprocess, 389.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 564.3ms
# Speed: 13.7ms preprocess, 564.3ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 193.4ms
# Speed: 5.5ms preprocess, 193.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 182.1ms
# Speed: 2.8ms preprocess, 182.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 575.5ms
# Speed: 3.3ms preprocess, 575.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 189.9ms
# Speed: 6.2ms preprocess, 189.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 200.0ms
# Speed: 2.7ms preprocess, 200.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 persons, 184.4ms
# Speed: 5.8ms preprocess, 184.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 176.6ms
# Speed: 3.0ms preprocess, 176.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 186.6ms
# Speed: 4.8ms preprocess, 186.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 348.6ms
# Speed: 3.3ms preprocess, 348.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 190.6ms
# Speed: 3.2ms preprocess, 190.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 179.8ms
# Speed: 5.2ms preprocess, 179.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 183.9ms
# Speed: 3.0ms preprocess, 183.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 persons, 179.1ms
# Speed: 5.3ms preprocess, 179.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 202.8ms
# Speed: 2.6ms preprocess, 202.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 256.2ms
# Speed: 8.6ms preprocess, 256.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 175.2ms
# Speed: 2.4ms preprocess, 175.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 191.2ms
# Speed: 9.8ms preprocess, 191.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 167.2ms
# Speed: 5.0ms preprocess, 167.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 180.8ms
# Speed: 6.6ms preprocess, 180.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 549.2ms
# Speed: 6.0ms preprocess, 549.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 483.3ms
# Speed: 3.9ms preprocess, 483.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 257.1ms
# Speed: 6.3ms preprocess, 257.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 344.2ms
# Speed: 2.6ms preprocess, 344.2ms inference, 12.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 398.6ms
# Speed: 6.1ms preprocess, 398.6ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 persons, 241.5ms
# Speed: 2.8ms preprocess, 241.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 276.6ms
# Speed: 5.8ms preprocess, 276.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 201.6ms
# Speed: 3.1ms preprocess, 201.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 176.6ms
# Speed: 2.7ms preprocess, 176.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 210.6ms
# Speed: 6.4ms preprocess, 210.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 237.3ms
# Speed: 3.1ms preprocess, 237.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 370.2ms
# Speed: 8.7ms preprocess, 370.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 368.0ms
# Speed: 4.9ms preprocess, 368.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 385.3ms
# Speed: 5.4ms preprocess, 385.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 425.9ms
# Speed: 3.8ms preprocess, 425.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 253.3ms
# Speed: 6.9ms preprocess, 253.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 194.0ms
# Speed: 2.8ms preprocess, 194.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 217.6ms
# Speed: 5.6ms preprocess, 217.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 persons, 284.0ms
# Speed: 9.6ms preprocess, 284.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 332.4ms
# Speed: 6.2ms preprocess, 332.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 261.2ms
# Speed: 5.2ms preprocess, 261.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 206.7ms
# Speed: 5.2ms preprocess, 206.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 366.3ms
# Speed: 6.9ms preprocess, 366.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 181.3ms
# Speed: 5.2ms preprocess, 181.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 317.1ms
# Speed: 3.0ms preprocess, 317.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 265.1ms
# Speed: 6.9ms preprocess, 265.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 27 persons, 435.8ms
# Speed: 9.1ms preprocess, 435.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 227.3ms
# Speed: 6.1ms preprocess, 227.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 209.8ms
# Speed: 5.7ms preprocess, 209.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 359.0ms
# Speed: 6.8ms preprocess, 359.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 216.2ms
# Speed: 2.9ms preprocess, 216.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 persons, 256.8ms
# Speed: 3.0ms preprocess, 256.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 268.9ms
# Speed: 7.1ms preprocess, 268.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 219.5ms
# Speed: 2.7ms preprocess, 219.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 213.9ms
# Speed: 6.6ms preprocess, 213.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 persons, 186.6ms
# Speed: 4.0ms preprocess, 186.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 248.5ms
# Speed: 6.4ms preprocess, 248.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 625.7ms
# Speed: 4.0ms preprocess, 625.7ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 266.3ms
# Speed: 3.2ms preprocess, 266.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 639.8ms
# Speed: 5.1ms preprocess, 639.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 221.1ms
# Speed: 3.5ms preprocess, 221.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 204.8ms
# Speed: 5.9ms preprocess, 204.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 209.1ms
# Speed: 5.4ms preprocess, 209.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 318.2ms
# Speed: 7.3ms preprocess, 318.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 178.0ms
# Speed: 2.7ms preprocess, 178.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 178.9ms
# Speed: 4.9ms preprocess, 178.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 179.7ms
# Speed: 2.6ms preprocess, 179.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 173.6ms
# Speed: 5.0ms preprocess, 173.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 179.9ms
# Speed: 5.6ms preprocess, 179.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 181.1ms
# Speed: 6.1ms preprocess, 181.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 188.3ms
# Speed: 4.5ms preprocess, 188.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 183.6ms
# Speed: 5.2ms preprocess, 183.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 175.0ms
# Speed: 5.0ms preprocess, 175.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 177.9ms
# Speed: 5.5ms preprocess, 177.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 170.2ms
# Speed: 2.6ms preprocess, 170.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 170.9ms
# Speed: 5.6ms preprocess, 170.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 238.2ms
# Speed: 3.1ms preprocess, 238.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 268.3ms
# Speed: 2.8ms preprocess, 268.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 227.7ms
# Speed: 2.9ms preprocess, 227.7ms inference, 10.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 284.4ms
# Speed: 5.3ms preprocess, 284.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 186.1ms
# Speed: 3.3ms preprocess, 186.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 281.3ms
# Speed: 3.4ms preprocess, 281.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 persons, 222.8ms
# Speed: 6.4ms preprocess, 222.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 208.7ms
# Speed: 3.1ms preprocess, 208.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 241.1ms
# Speed: 8.8ms preprocess, 241.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 323.0ms
# Speed: 3.7ms preprocess, 323.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 519.6ms
# Speed: 4.3ms preprocess, 519.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 persons, 308.5ms
# Speed: 3.4ms preprocess, 308.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 261.8ms
# Speed: 6.0ms preprocess, 261.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 389.4ms
# Speed: 3.2ms preprocess, 389.4ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 306.4ms
# Speed: 3.6ms preprocess, 306.4ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 287.1ms
# Speed: 3.8ms preprocess, 287.1ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 persons, 473.9ms
# Speed: 11.3ms preprocess, 473.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 364.9ms
# Speed: 8.0ms preprocess, 364.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 577.6ms
# Speed: 6.5ms preprocess, 577.6ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 329.3ms
# Speed: 3.0ms preprocess, 329.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 227.1ms
# Speed: 6.0ms preprocess, 227.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 273.0ms
# Speed: 3.8ms preprocess, 273.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 234.2ms
# Speed: 3.4ms preprocess, 234.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 407.3ms
# Speed: 4.6ms preprocess, 407.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 254.0ms
# Speed: 5.9ms preprocess, 254.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 270.5ms
# Speed: 5.6ms preprocess, 270.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 persons, 191.0ms
# Speed: 2.7ms preprocess, 191.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 182.3ms
# Speed: 5.1ms preprocess, 182.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 194.3ms
# Speed: 2.7ms preprocess, 194.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 171.8ms
# Speed: 3.8ms preprocess, 171.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 180.9ms
# Speed: 5.3ms preprocess, 180.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 305.1ms
# Speed: 3.3ms preprocess, 305.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 209.5ms
# Speed: 10.8ms preprocess, 209.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 178.0ms
# Speed: 4.0ms preprocess, 178.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 271.5ms
# Speed: 8.6ms preprocess, 271.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 275.3ms
# Speed: 2.9ms preprocess, 275.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 567.0ms
# Speed: 6.0ms preprocess, 567.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 357.9ms
# Speed: 4.0ms preprocess, 357.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 328.9ms
# Speed: 6.9ms preprocess, 328.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 186.4ms
# Speed: 7.9ms preprocess, 186.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 317.7ms
# Speed: 6.2ms preprocess, 317.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 305.7ms
# Speed: 5.7ms preprocess, 305.7ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 308.8ms
# Speed: 7.7ms preprocess, 308.8ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 270.2ms
# Speed: 9.8ms preprocess, 270.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 350.1ms
# Speed: 15.9ms preprocess, 350.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 263.4ms
# Speed: 2.9ms preprocess, 263.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 238.3ms
# Speed: 5.8ms preprocess, 238.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 196.4ms
# Speed: 2.7ms preprocess, 196.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 273.3ms
# Speed: 7.5ms preprocess, 273.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 172.3ms
# Speed: 2.6ms preprocess, 172.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 177.4ms
# Speed: 4.8ms preprocess, 177.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 308.6ms
# Speed: 5.4ms preprocess, 308.6ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 292.5ms
# Speed: 3.1ms preprocess, 292.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 194.5ms
# Speed: 5.8ms preprocess, 194.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 218.7ms
# Speed: 4.8ms preprocess, 218.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 166.7ms
# Speed: 5.3ms preprocess, 166.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 166.3ms
# Speed: 3.2ms preprocess, 166.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 25 persons, 168.6ms
# Speed: 4.9ms preprocess, 168.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 193.0ms
# Speed: 2.7ms preprocess, 193.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 171.0ms
# Speed: 6.1ms preprocess, 171.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 173.7ms
# Speed: 2.5ms preprocess, 173.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 181.3ms
# Speed: 4.8ms preprocess, 181.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 180.2ms
# Speed: 5.6ms preprocess, 180.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 174.8ms
# Speed: 5.2ms preprocess, 174.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 170.3ms
# Speed: 5.8ms preprocess, 170.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 162.7ms
# Speed: 3.7ms preprocess, 162.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 167.5ms
# Speed: 3.9ms preprocess, 167.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 174.0ms
# Speed: 5.1ms preprocess, 174.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 193.1ms
# Speed: 2.7ms preprocess, 193.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 176.4ms
# Speed: 6.8ms preprocess, 176.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 172.9ms
# Speed: 2.7ms preprocess, 172.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 167.4ms
# Speed: 4.7ms preprocess, 167.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 194.8ms
# Speed: 4.1ms preprocess, 194.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 228.6ms
# Speed: 6.0ms preprocess, 228.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 173.8ms
# Speed: 5.0ms preprocess, 173.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 170.9ms
# Speed: 4.8ms preprocess, 170.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 199.9ms
# Speed: 2.6ms preprocess, 199.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 168.2ms
# Speed: 2.6ms preprocess, 168.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 197.2ms
# Speed: 7.0ms preprocess, 197.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 241.6ms
# Speed: 3.1ms preprocess, 241.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 284.6ms
# Speed: 10.8ms preprocess, 284.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 200.9ms
# Speed: 4.7ms preprocess, 200.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 167.6ms
# Speed: 5.4ms preprocess, 167.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 202.6ms
# Speed: 2.9ms preprocess, 202.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 170.1ms
# Speed: 2.7ms preprocess, 170.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 200.5ms
# Speed: 8.1ms preprocess, 200.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 188.7ms
# Speed: 2.7ms preprocess, 188.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 167.5ms
# Speed: 5.5ms preprocess, 167.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 169.1ms
# Speed: 2.7ms preprocess, 169.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 176.7ms
# Speed: 4.9ms preprocess, 176.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 174.8ms
# Speed: 2.6ms preprocess, 174.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 184.7ms
# Speed: 7.2ms preprocess, 184.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 persons, 193.6ms
# Speed: 7.9ms preprocess, 193.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 161.8ms
# Speed: 5.0ms preprocess, 161.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 238.5ms
# Speed: 2.9ms preprocess, 238.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 616.4ms
# Speed: 2.7ms preprocess, 616.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 194.7ms
# Speed: 5.4ms preprocess, 194.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 160.8ms
# Speed: 2.8ms preprocess, 160.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 199.9ms
# Speed: 5.6ms preprocess, 199.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 197.1ms
# Speed: 3.4ms preprocess, 197.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 194.5ms
# Speed: 4.9ms preprocess, 194.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 193.7ms
# Speed: 3.0ms preprocess, 193.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 200.0ms
# Speed: 4.6ms preprocess, 200.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 234.2ms
# Speed: 21.0ms preprocess, 234.2ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 349.4ms
# Speed: 3.7ms preprocess, 349.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 280.4ms
# Speed: 9.5ms preprocess, 280.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 persons, 167.3ms
# Speed: 3.1ms preprocess, 167.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 197.7ms
# Speed: 5.3ms preprocess, 197.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 776.0ms
# Speed: 4.4ms preprocess, 776.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 938.7ms
# Speed: 7.8ms preprocess, 938.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 970.9ms
# Speed: 4.4ms preprocess, 970.9ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 190.8ms
# Speed: 6.5ms preprocess, 190.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 464.5ms
# Speed: 35.5ms preprocess, 464.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 993.8ms
# Speed: 6.7ms preprocess, 993.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 610.9ms
# Speed: 5.3ms preprocess, 610.9ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 284.6ms
# Speed: 6.2ms preprocess, 284.6ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 192.2ms
# Speed: 6.0ms preprocess, 192.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 404.2ms
# Speed: 10.0ms preprocess, 404.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 persons, 169.5ms
# Speed: 2.8ms preprocess, 169.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 persons, 278.5ms
# Speed: 3.3ms preprocess, 278.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 230.2ms
# Speed: 5.7ms preprocess, 230.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 192.2ms
# Speed: 2.7ms preprocess, 192.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 196.7ms
# Speed: 2.7ms preprocess, 196.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 182.6ms
# Speed: 5.6ms preprocess, 182.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 persons, 212.4ms
# Speed: 2.6ms preprocess, 212.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 234.7ms
# Speed: 10.1ms preprocess, 234.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 329.0ms
# Speed: 5.4ms preprocess, 329.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 182.9ms
# Speed: 5.9ms preprocess, 182.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 789.9ms
# Speed: 2.7ms preprocess, 789.9ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 216.1ms
# Speed: 3.0ms preprocess, 216.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 163.8ms
# Speed: 4.9ms preprocess, 163.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 164.3ms
# Speed: 2.8ms preprocess, 164.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 223.7ms
# Speed: 7.1ms preprocess, 223.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 217.3ms
# Speed: 2.7ms preprocess, 217.3ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 177.4ms
# Speed: 4.3ms preprocess, 177.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 168.6ms
# Speed: 5.4ms preprocess, 168.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 175.8ms
# Speed: 2.7ms preprocess, 175.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 163.0ms
# Speed: 5.4ms preprocess, 163.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 159.2ms
# Speed: 2.6ms preprocess, 159.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 208.6ms
# Speed: 7.8ms preprocess, 208.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 196.9ms
# Speed: 2.7ms preprocess, 196.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 187.5ms
# Speed: 5.1ms preprocess, 187.5ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 164.6ms
# Speed: 5.2ms preprocess, 164.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 25 persons, 164.8ms
# Speed: 5.2ms preprocess, 164.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 181.4ms
# Speed: 2.7ms preprocess, 181.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 178.9ms
# Speed: 2.8ms preprocess, 178.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 456.0ms
# Speed: 7.0ms preprocess, 456.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 822.7ms
# Speed: 27.1ms preprocess, 822.7ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 179.2ms
# Speed: 5.5ms preprocess, 179.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 299.8ms
# Speed: 8.1ms preprocess, 299.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 176.6ms
# Speed: 5.1ms preprocess, 176.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 179.6ms
# Speed: 2.7ms preprocess, 179.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 178.1ms
# Speed: 5.3ms preprocess, 178.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 188.0ms
# Speed: 2.7ms preprocess, 188.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 208.1ms
# Speed: 4.9ms preprocess, 208.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 156.0ms
# Speed: 2.6ms preprocess, 156.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 199.8ms
# Speed: 8.0ms preprocess, 199.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 210.2ms
# Speed: 2.9ms preprocess, 210.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 170.1ms
# Speed: 6.5ms preprocess, 170.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 164.3ms
# Speed: 5.5ms preprocess, 164.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 164.7ms
# Speed: 2.7ms preprocess, 164.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 264.1ms
# Speed: 3.6ms preprocess, 264.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 179.2ms
# Speed: 5.8ms preprocess, 179.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 505.7ms
# Speed: 2.7ms preprocess, 505.7ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 196.1ms
# Speed: 2.8ms preprocess, 196.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 201.4ms
# Speed: 6.5ms preprocess, 201.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 183.8ms
# Speed: 2.7ms preprocess, 183.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 202.9ms
# Speed: 5.2ms preprocess, 202.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 187.4ms
# Speed: 3.1ms preprocess, 187.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 179.7ms
# Speed: 2.8ms preprocess, 179.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 198.4ms
# Speed: 4.7ms preprocess, 198.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 183.0ms
# Speed: 7.5ms preprocess, 183.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 198.1ms
# Speed: 2.6ms preprocess, 198.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 264.0ms
# Speed: 2.7ms preprocess, 264.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 178.8ms
# Speed: 5.2ms preprocess, 178.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 179.4ms
# Speed: 2.6ms preprocess, 179.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 208.1ms
# Speed: 5.8ms preprocess, 208.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 167.7ms
# Speed: 3.4ms preprocess, 167.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 185.3ms
# Speed: 3.4ms preprocess, 185.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 247.2ms
# ...
# Speed: 2.7ms preprocess, 236.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 162.4ms
# Speed: 2.5ms preprocess, 162.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 175.0ms
# Speed: 6.8ms preprocess, 175.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 200.7ms
# Speed: 2.6ms preprocess, 200.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 175.3ms
# Speed: 5.8ms preprocess, 175.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 169.3ms
# Speed: 2.6ms preprocess, 169.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 228.4ms
# Speed: 5.3ms preprocess, 228.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 172.8ms
# Speed: 2.5ms preprocess, 172.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 persons, 171.8ms
# Speed: 5.0ms preprocess, 171.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 persons, 223.4ms
# Speed: 5.6ms preprocess, 223.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 163.0ms
# Speed: 6.3ms preprocess, 163.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 162.9ms
# Speed: 3.3ms preprocess, 162.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 246.7ms
# Speed: 2.8ms preprocess, 246.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 172.8ms
# Speed: 4.9ms preprocess, 172.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 178.6ms
# Speed: 2.6ms preprocess, 178.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 205.7ms
# Speed: 5.0ms preprocess, 205.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 167.2ms
# Speed: 2.9ms preprocess, 167.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 188.5ms
# Speed: 5.4ms preprocess, 188.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 210.9ms
# Speed: 2.6ms preprocess, 210.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 172.0ms
# Speed: 5.1ms preprocess, 172.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 163.8ms
# Speed: 5.2ms preprocess, 163.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 206.2ms
# Speed: 4.8ms preprocess, 206.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 173.6ms
# Speed: 2.6ms preprocess, 173.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 164.7ms
# Speed: 2.6ms preprocess, 164.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 214.7ms
# Speed: 5.6ms preprocess, 214.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 163.6ms
# Speed: 2.5ms preprocess, 163.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 168.9ms
# Speed: 7.1ms preprocess, 168.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 205.3ms
# Speed: 3.4ms preprocess, 205.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 170.0ms
# Speed: 5.5ms preprocess, 170.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 171.0ms
# Speed: 2.6ms preprocess, 171.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 202.2ms
# Speed: 5.9ms preprocess, 202.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 161.9ms
# Speed: 4.9ms preprocess, 161.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 persons, 171.0ms
# Speed: 6.5ms preprocess, 171.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 persons, 205.2ms
# Speed: 3.7ms preprocess, 205.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 180.7ms
# Speed: 3.3ms preprocess, 180.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 168.4ms
# Speed: 5.9ms preprocess, 168.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 220.2ms
# Speed: 3.5ms preprocess, 220.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 174.8ms
# Speed: 5.1ms preprocess, 174.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 160.3ms
# Speed: 3.9ms preprocess, 160.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 212.0ms
# Speed: 6.4ms preprocess, 212.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 174.5ms
# Speed: 2.6ms preprocess, 174.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 170.6ms
# Speed: 4.8ms preprocess, 170.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 persons, 209.5ms
# Speed: 4.8ms preprocess, 209.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 163.2ms
# Speed: 5.1ms preprocess, 163.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 169.2ms
# Speed: 2.6ms preprocess, 169.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 217.9ms
# Speed: 2.7ms preprocess, 217.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 202.9ms
# Speed: 5.6ms preprocess, 202.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 persons, 172.2ms
# Speed: 2.8ms preprocess, 172.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 224.6ms
# Speed: 5.6ms preprocess, 224.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 167.8ms
# Speed: 2.5ms preprocess, 167.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 190.0ms
# Speed: 5.4ms preprocess, 190.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 211.0ms
# Speed: 2.6ms preprocess, 211.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 170.3ms
# Speed: 5.0ms preprocess, 170.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 173.7ms
# Speed: 5.8ms preprocess, 173.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 205.6ms
# Speed: 4.4ms preprocess, 205.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 178.1ms
# Speed: 2.5ms preprocess, 178.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 161.2ms
# Speed: 2.6ms preprocess, 161.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 210.4ms
# Speed: 6.1ms preprocess, 210.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 persons, 191.8ms
# Speed: 2.6ms preprocess, 191.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 171.2ms
# Speed: 5.2ms preprocess, 171.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 202.4ms
# Speed: 2.5ms preprocess, 202.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 178.9ms
# Speed: 6.4ms preprocess, 178.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 171.6ms
# Speed: 2.6ms preprocess, 171.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 224.7ms
# Speed: 5.4ms preprocess, 224.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 164.0ms
# Speed: 5.0ms preprocess, 164.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 162.3ms
# Speed: 5.2ms preprocess, 162.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 213.5ms
# Speed: 2.5ms preprocess, 213.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 177.5ms
# Speed: 2.6ms preprocess, 177.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 170.1ms
# Speed: 5.1ms preprocess, 170.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 220.6ms
# Speed: 2.8ms preprocess, 220.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 207.2ms
# Speed: 5.6ms preprocess, 207.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 164.9ms
# Speed: 2.7ms preprocess, 164.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 217.1ms
# Speed: 6.3ms preprocess, 217.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 172.6ms
# Speed: 3.0ms preprocess, 172.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 174.5ms
# Speed: 4.9ms preprocess, 174.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 216.6ms
# Speed: 2.6ms preprocess, 216.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 168.0ms
# Speed: 5.3ms preprocess, 168.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 163.5ms
# Speed: 2.6ms preprocess, 163.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 221.9ms
# Speed: 4.6ms preprocess, 221.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 164.5ms
# Speed: 2.7ms preprocess, 164.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 160.7ms
# Speed: 5.2ms preprocess, 160.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 206.4ms
# Speed: 2.3ms preprocess, 206.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 179.8ms
# Speed: 3.1ms preprocess, 179.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 182.1ms
# Speed: 5.0ms preprocess, 182.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 223.6ms
# Speed: 3.2ms preprocess, 223.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 173.2ms
# Speed: 6.3ms preprocess, 173.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 177.8ms
# Speed: 5.8ms preprocess, 177.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 221.4ms
# Speed: 2.8ms preprocess, 221.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 persons, 174.2ms
# Speed: 2.6ms preprocess, 174.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 176.7ms
# Speed: 4.9ms preprocess, 176.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 208.9ms
# Speed: 3.2ms preprocess, 208.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 172.8ms
# Speed: 3.4ms preprocess, 172.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 176.4ms
# Speed: 6.9ms preprocess, 176.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 persons, 214.9ms
# Speed: 2.3ms preprocess, 214.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 176.2ms
# Speed: 2.7ms preprocess, 176.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 240.0ms
# Speed: 6.7ms preprocess, 240.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 214.4ms
# Speed: 2.8ms preprocess, 214.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 persons, 213.0ms
# Speed: 6.8ms preprocess, 213.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 persons, 211.7ms
# Speed: 4.9ms preprocess, 211.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 248.5ms
# Speed: 5.5ms preprocess, 248.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 213.7ms
# Speed: 3.1ms preprocess, 213.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 195.9ms
# Speed: 5.4ms preprocess, 195.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 persons, 240.9ms
# Speed: 2.4ms preprocess, 240.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 200.3ms
# Speed: 5.1ms preprocess, 200.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 206.5ms
# Speed: 3.5ms preprocess, 206.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 263.0ms
# Speed: 6.1ms preprocess, 263.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 persons, 201.3ms
# Speed: 3.3ms preprocess, 201.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 270.7ms
# Speed: 12.9ms preprocess, 270.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 persons, 293.4ms
# Speed: 3.9ms preprocess, 293.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 232.7ms
# Speed: 5.3ms preprocess, 232.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 277.0ms
# Speed: 2.5ms preprocess, 277.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 253.6ms
# Speed: 6.8ms preprocess, 253.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 166.8ms
# Speed: 3.7ms preprocess, 166.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 persons, 185.7ms
# Speed: 4.8ms preprocess, 185.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 persons, 217.6ms
# Speed: 4.5ms preprocess, 217.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 169.8ms
# Speed: 5.2ms preprocess, 169.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 13 persons, 317.7ms
# Speed: 2.9ms preprocess, 317.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 210.4ms
# Speed: 6.8ms preprocess, 210.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 183.2ms
# Speed: 2.6ms preprocess, 183.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 persons, 169.2ms
# Speed: 6.1ms preprocess, 169.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 persons, 243.6ms
# Speed: 2.6ms preprocess, 243.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 persons, 213.9ms
# Speed: 4.4ms preprocess, 213.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 12 persons, 177.7ms
# Speed: 2.6ms preprocess, 177.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [Task 3] Epoch 3/3 - Loss: 0.000000

# %%
# ======================================================
# Save Mall-Adapted CSRNet Model
# ======================================================

SAVE_PATH = "csrnet_mall_adapted.pth"
torch.save(model.state_dict(), SAVE_PATH)

print(f"Saved fine-tuned model to: {SAVE_PATH}")
# Out:
# Saved fine-tuned model to: csrnet_mall_adapted.pth
